# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
#from IPython.display import display
from scripts.db import *
from scripts.plots import *
from scripts.stats import *

# %%
downloadFile()
join ()
# Out:
# Starting download, please wait
# Donload finish
# 'SESION tiene 238 entradas.'
# 'SESION paso a tener 238 entradas.'
# 'INICIONIVEL tiene 328 entradas.'
# 'INICIONIVEL paso a tener 328 entradas.'
# 'RESULTADOS tiene 271 entradas.'
# 'RESULTADOS paso a tener 272 entradas.'

# %%
#updateUser('TurinUTDT2')
#listOfUsersClean()
#updateListOfUsers()
#pandasTransferencia().columns
#sessionStats()
#pandasUtilPiloto()
plotByUser(onlyOneUser=True, number=-3, join=True, filtroCompletadoActivo=False)
# plotParalelismos(soloCompletados=False)
##listOfUsers()
#updateListOfUsers()
# Out:
# 'ParalelismoTutorial'
# 'AngulosTutorial'
# 'TESTP30'
# 'TESTP60'
# 'TESTP120'
# 'TESTP150'
# 'TESTA30'
# 'TESTA60'
# 'TESTA120'
# 'TESTA150'
# 'ENTRENAMIENTOA30INICIAL'
# 'ENTRENAMIENTOA30MEDIO'
# 'ENTRENAMIENTOA30FINAL'

# %%
lastSessionStats()
listOfUsersClean()
# Out:
# 'El usuario pru inicio sesion el 2016-09-05 17:48:11.211999 y juego 10 niveles.'
# ' Level ParalelismoTutorial jugado a las: 2016-09-05 17:48:19.903000 Envio de datos terminado a las: 2016-09-05 17:48:25.443000'
# ' Level AngulosTutorial jugado a las: 2016-09-05 17:48:28.247999 Envio de datos terminado a las: 2016-09-05 17:48:32.921999'
# ' Level TESTP30 jugado a las: 2016-09-05 17:48:34.417999 Envio de datos terminado a las: 2016-09-05 17:48:50.986999'
# ' Level TESTP60 jugado a las: 2016-09-05 17:48:53.029000 Envio de datos terminado a las: 2016-09-05 17:49:07.660000'
# ' Level TESTP120 jugado a las: 2016-09-05 17:49:09.382999 Envio de datos terminado a las: 2016-09-05 17:49:33.068000'
# ' Level TESTP150 jugado a las: 2016-09-05 17:49:35.230999 Envio de datos terminado a las: 2016-09-05 17:49:50.621999'
# ' Level TESTA30 jugado a las: 2016-09-05 17:49:51.427999 Envio de datos terminado a las: 2016-09-05 17:50:06.303999'
# ...

# %%
pandasTransferencia()[pandasTransferencia()['levelInstance']==1471990352046]
#pandasTransferencia()['levelInstance']
# Out:
#      alias         userId ignore  CodeVersion  EnvioInstance Finalizado  \
# 4138   mmm  1471987051104  False           41  1471990581648       True
# 4139   mmm  1471987051104  False           41  1471990581648       True
# 4140   mmm  1471987051104  False           41  1471990581648       True
# 4141   mmm  1471987051104  False           41  1471990581648       True
# 4142   mmm  1471987051104  False           41  1471990581648       True
# 4143   mmm  1471987051104  False           41  1471990581648       True
# 4144   mmm  1471987051104  False           41  1471990581648       True
# 4145   mmm  1471987051104  False           41  1471990581648       True
# 4146   mmm  1471987051104  False           41  1471990581648       True
# 4147   mmm  1471987051104  False           41  1471990581648       True
# 4148   mmm  1471987051104  False           41  1471990581648       True
# 4149   mmm  1471987051104  False           41  1471990581648       True
# ...

# %%
sessionStats()
# Out:
# 'El usuario PruebasCalibracionUTDT1 inicio sesion el 2016-07-21 17:56:28.328999 y juego 2 niveles.'
# ' Level ParalelismoTutorial jugado a las: 2016-07-21 17:56:42.253999 Envio de datos terminado a las: 2016-07-21 17:58:22.098000'
# ' Level AngulosTutorial jugado a las: 2016-07-21 17:58:27.776999 Envio de datos terminado a las: 2016-07-21 17:59:51.078999'
# 'El usuario PruebasCalibracionUTDT1 inicio sesion el 2016-07-21 18:05:15.724999 y juego 3 niveles.'
# ' Level TESTP30 jugado a las: 2016-07-21 18:05:21.575999 Envio de datos terminado a las: 2016-07-21 18:22:51.904000'
# ' Level TESTP30 jugado a las: 2016-07-21 18:30:21.482000 Envio de datos terminado a las: 2016-07-21 18:43:00.720000'
# ' Level TESTP30 jugado a las: 2016-07-21 18:48:00.816999 Envio de datos terminado a las: 2016-07-21 18:59:21.325000'
# 'El usuario PruebasCalibracionUTDT1 inicio sesion el 2016-07-22 11:21:53.993000 y juego 4 niveles.'
# ...

# %%
plotByUser(['Pierina'])

# %%
#statsUser = statByUser(['MartaMaule'])
stats = statByUser(['Jose',
 'OliviaUTDT',
 'Fede Roli',
 'Martina',
 'Lungo',
 'AgustinUTDT',
 'GuidoUTDT',
 'FlorLisazo',
 'EugeSiele',
 'JuleReves',
 'MartaMaule',
 'fallido',
 'Chalu',
 'ChaluPosta',
 'ChechuZaza',
 'Pierina'])

# %%
cualitativeStatsPlot(stats)
cuantitativeStatsPlotParalelismo(stats)
cuantitativeStatsPlotAngulos(stats)

# %%
display(stats[(stats['pValueCorrectas']<0.05)&(stats['pValueCorrectas']>0.01)][['meanValue','pValueCorrectas']])
# Out:
#     meanValue  pValueCorrectas
# 0    0.588380         0.020695
# 0    0.174055         0.031784
# 0    0.251983         0.017578
# 0   65.333333         0.030828
# 0    0.588779         0.024521
# 0    0.476309         0.017345
# 0   90.666667         0.012973
# 0    0.433147         0.015442
# 0    1.408262         0.031784
# 0    0.118151         0.017345
# 0    0.145233         0.015442
# 0    1.578186         0.013302
# 0    2.692540         0.031784
# 0   63.666667         0.024072
# 0    3.401888         0.031784
# 0    1.745819         0.039177
# 0   23.333333         0.045267
# 0  113.333333         0.042422
# 0  189.333333         0.018637
#
# [19 rows x 2 columns]

# %%
display(stats)
# Out:
#    contar deteccionCorrecta deteccionInCorrecta evolucionDetectada  \
# 0       1              True               False              False
# 0       1             False               False              False
# 0       1             False               False              False
# 0       1              True               False              False
# 0       1              True               False              False
# 0       1              True               False              False
# 0       1              True               False              False
# 0       1              True               False              False
# 0       1              True               False              False
# 0       1              True               False               True
# 0       1              True               False              False
# 0       1              True               False              False
# 0       1              True               False              False
# ...
