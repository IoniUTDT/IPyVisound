# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from scripts.db import *
from scripts.plots import *
from scripts.stats import *
from scripts.statsTransferencia import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

resumen = dataNumerica()
data = pd.DataFrame.from_dict(resumen, orient='index')

#Trasnformamos los valores que interesan en columnas (Por ahora voy a hacer todo en angulos)
dataTest = pd.DataFrame()
dataTestI = pd.DataFrame()
dataTestF = pd.DataFrame()
for i, col in enumerate(["P30", "P60", "P120","P150","A30","A60","A120","A150"]):
    dataTestI["I"+col] = data['TestInicialAngulos'].map(lambda x: x[i])
    dataTest["I"+col] = data['TestInicialAngulos'].map(lambda x: x[i])
for i, col in enumerate(["P30", "P60", "P120","P150","A30","A60","A120","A150"]):
    dataTestF["F"+col] = data['TestFinalAngulos'].map(lambda x: x[i])
    dataTest["F"+col] = data['TestFinalAngulos'].map(lambda x: x[i]) 

print (dataTest['IP30'])
print (data['Orientacion'])
# Out:
# /home/ionatan/Gits/IPyVisound/scripts/statsTransferencia.py:536: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#
# /home/ionatan/Gits/IPyVisound/scripts/statsTransferencia.py:508: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   if alias == "ExpT_Julieta":
# Sujeto01    57.5
# Sujeto02    54.5
# Sujeto03    30.0
# Sujeto04    28.0
# Sujeto05    30.0
# Sujeto06    64.0
# Sujeto07    19.5
# Sujeto08    32.0
# Sujeto09    31.5
# Sujeto10    43.5
# Name: IP30, dtype: float64
# Sujeto01        A30
# Sujeto02        A30
# Sujeto03        P30
# Sujeto04        P30
# Sujeto05        P30
# Sujeto06    CONTROL
# Sujeto07    CONTROL
# Sujeto08    CONTROL
# Sujeto09    CONTROL
# Sujeto10    CONTROL
# Name: Orientacion, dtype: object
# /home/ionatan/Gits/IPyVisound/scripts/statsTransferencia.py:510: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

sns.set()
fig, ax = plt.subplots(1,2)
fig.set_size_inches(30,15)
ax[0].axis('off')
ax[1].axis('off')

cbar_ax = fig.add_axes([0.92, 0.05, 0.03, 0.7])
cbar_ax.tick_params(labelsize=30)
cbar_ax.text(-0.3,0.5,'Angulo umbral de deteccion correcta',size=30, horizontalalignment='center', verticalalignment='center', rotation='vertical')
ax[0].tick_params(labelsize=30)
ax[1].tick_params(labelsize=30)
sns.heatmap(dataTestF, vmax=80, annot=True, annot_kws={"size": 15}, ax=ax[1], cbar_ax=cbar_ax)
sns.heatmap(dataTestI, vmax=80, annot=True, annot_kws={"size": 15}, ax=ax[0], cbar=False)

ax[0].vlines(4, 0, 10, colors=sns.color_palette()[3], lw=10)
ax[1].vlines(4, 0, 10, colors=sns.color_palette()[3], lw=10)
ax[0].hlines(5, 0, 10, colors=sns.color_palette()[4], lw=10)
ax[1].hlines(5, 0, 10, colors=sns.color_palette()[4], lw=10)
ax[0].hlines(8, 0, 10, colors=sns.color_palette()[4], lw=5)
ax[1].hlines(8, 0, 10, colors=sns.color_palette()[4], lw=5)
# ax[0].set_title('Test Inicial', fontdict={"fontsize": 30})
# ax[1].set_title('Test Final', fontdict={"fontsize": 30})

ax[0].text(4,11,'TEST INICIAL',size=40, horizontalalignment='center', verticalalignment='center')
ax[1].text(4,11,'TEST FINAL',size=40, horizontalalignment='center', verticalalignment='center')

ax[0].text(2,10.5,'Paralelismo',size=30, horizontalalignment='center', verticalalignment='center')
ax[0].text(6,10.5,'Angulos',size=30, horizontalalignment='center', verticalalignment='center')

ax[0].text(0.5,10.1,'30º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(1.5,10.1,'60º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(2.5,10.1,'120º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(3.5,10.1,'150º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(4.5,10.1,'30º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(5.5,10.1,'60º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(6.5,10.1,'120º',size=20, horizontalalignment='center', verticalalignment='center')
ax[0].text(7.5,10.1,'150º',size=20, horizontalalignment='center', verticalalignment='center')

ax[1].text(0.5,10.1,'30º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(1.5,10.1,'60º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(2.5,10.1,'120º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(3.5,10.1,'150º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(4.5,10.1,'30º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(5.5,10.1,'60º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(6.5,10.1,'120º',size=20, horizontalalignment='center', verticalalignment='center')
ax[1].text(7.5,10.1,'150º',size=20, horizontalalignment='center', verticalalignment='center')


ax[1].text(2,10.5,'Paralelismo',size=30, horizontalalignment='center', verticalalignment='center')
ax[1].text(6,10.5,'Angulos',size=30, horizontalalignment='center', verticalalignment='center')

ax[0].text(-1,2.5,'CONTROL', size=40, horizontalalignment='center', verticalalignment='center', rotation='vertical')
ax[0].text(-1,7.5,'ENTRENAMIENTO', size=40, horizontalalignment='center', verticalalignment='center', rotation='vertical')
ax[0].text(-0.3,6.5,'Paralelismo', size=30, horizontalalignment='center', verticalalignment='center', rotation='vertical')
ax[0].text(-0.3,9,'Angulos', size=30, horizontalalignment='center', verticalalignment='center', rotation='vertical')

# Agregamos el recuadro rojo en lo entrenado
for i in range(2):
    ax[i].vlines(4+0.05,8,10, colors=sns.color_palette()[2], lw=10)
    ax[i].vlines(5-0.05,8,10, colors=sns.color_palette()[2], lw=10)
    ax[i].hlines(5+0.05,0,1, colors=sns.color_palette()[2], lw=10)
    ax[i].hlines(8-0.05,0,1, colors=sns.color_palette()[2], lw=10)
    
    ax[i].vlines(0+0.05,5,8, colors=sns.color_palette()[2], lw=10)
    ax[i].vlines(1-0.05,5,8, colors=sns.color_palette()[2], lw=10)
    ax[i].hlines(8+0.05,4,5, colors=sns.color_palette()[2], lw=10)
    ax[i].hlines(10-0.05,4,5, colors=sns.color_palette()[2], lw=10)
    
ax[1].text(9.7, 9, "orientacion entrenada", fontsize=30, ha='center', va='top')

cbar_ax.annotate('', xy=(9.7, 10), xytext=(9.7, 11), 
            arrowprops=dict(arrowstyle="<->", color='b'))

fig.tight_layout(rect=[0, 0, .9, 1])
fig.savefig('./Images/TransferenciaHeatmap', bbox_inches='tight')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/figure.py:1596: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#f, axarr = plt.subplots(1,2)

resumen
display(dataTestI)
#plt.sca(axarr[0])
p = sns.heatmap(dataTest)
ax.vlines(8, 0, 10, colors=sns.color_palette()[2])
p.fig.text(0.33, -0.01, "Bin: %s"%(n), ha ='left', fontsize = 15)
# Out:
#         IP30  IP60  IP120  IP150  IA30  IA60  IA120  IA150
# user01  57.5  17.0   34.0   39.5  79.6  78.4   79.6   79.6
# user02  54.5  19.5   70.0   37.5  78.0  76.0   59.6   22.4
# user03  30.0  18.0   34.5   26.0  70.8  77.2   48.4   21.2
# user04  28.0  10.5   28.5   34.5  79.6  68.8   61.6   42.0
# user05  30.0   8.5   16.5   34.5  77.2  56.8   38.0   55.6
# user06  64.0  27.0   30.0   68.0  63.2  78.4   79.2   79.6
# user07  19.5  10.0   93.0   80.0  77.6  79.6   74.4   62.0
# user08  32.0  13.0   14.0   40.0  67.6  47.2   79.6   66.0
# user09  31.5  25.5   22.0   63.0  61.6  61.6   20.4   74.8
# user10  43.5  11.0   15.0   94.0  79.6  79.6   79.6   67.6
#
# [10 rows x 8 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ffed4ba2a2fa> in <module>()
#       9 p = sns.heatmap(dataTest)
#      10 ax.vlines(8, 0, 10, colors=sns.color_palette()[2])
# ...

# %%
import seaborn as sns; sns.set()
import numpy as np; np.random.seed(0)
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
fig.set_size_inches(14, 7)
uniform_data = np.random.rand(10, 12)
cbar_ax = fig.add_axes([.92, .1, .02, .4])
sns.heatmap(uniform_data, ax=ax, cbar_ax=cbar_ax)
