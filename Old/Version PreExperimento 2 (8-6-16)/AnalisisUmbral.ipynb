# %%
# Cosas varias de forma

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from IPython.display import display

# %%
from scripts.extract import *
from scripts.umbral import *
#downloadFile()
#join()
#touchs, sounds = load(levelVersion=22, filtrarXUsuarioRegistrado=True)
#plotConvergencia(touchs, completo=False)
umbral = buscarUmbral(touchs, ordenado=True)
#plotResumen(buscarUmbral(touchs, ordenado=True))
# Out:
# /home/ionatan/Ipython/scripts/umbral.py:105: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   resumen = resumen.sort(['AnguloReferencia'], ascending=[True])

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
display(umbral)
# Out:
#      AnguloReferencia      AppVersion CumpleCriterioCola  DesviacionDeltaTita  \
# 109                -6  UmbralCompleto              False             0.935495
# 2                  -6  UmbralCompleto               True             0.347478
# 79                 -6  UmbralCompleto               True             1.682547
# 53                 -6  UmbralCompleto               True             0.588045
# 27                 -6  UmbralCompleto              False             0.256152
# 108                -3  UmbralCompleto               True             1.665043
# 54                 -3  UmbralCompleto               True             0.144674
# 80                 -3  UmbralCompleto              False             6.956022
# 4                  -3  UmbralCompleto               True             0.317592
# 28                 -3  UmbralCompleto               True             0.483793
# 81                  0  UmbralCompleto              False             0.825490
# 107                 0  UmbralCompleto               True             0.527697
# 55                  0  UmbralCompleto               True             0.104741
# 29                  0  UmbralCompleto               True             0.135942
# 3                   0  UmbralCompleto              False             0.797647
# 1                   0  UmbralCompleto              False             2.043345
# 106                 3  UmbralCompleto               True             2.635744
# 82                  3  UmbralCompleto               True             2.626529
# 56                  3  UmbralCompleto               True             0.276400
# 5                   3  UmbralCompleto               True             2.177728
# 30                  3  UmbralCompleto              False             0.290981
# 57                  6  UmbralCompleto               True             0.265225
# 105                 6  UmbralCompleto               True             2.098508
# 83                  6  UmbralCompleto               True             0.507089
# 6                   6  UmbralCompleto               True             1.351622
# 31                  6  UmbralCompleto               True             0.190748
# 58                 10  UmbralCompleto               True             0.870459
# 84                 10  UmbralCompleto               True             0.414043
# 32                 10  UmbralCompleto              False             0.330628
# 7                  10  UmbralCompleto              False             2.594953
# 59                 20  UmbralCompleto              False             2.557192
# 85                 20  UmbralCompleto               True             2.220326
# 33                 20  UmbralCompleto               True             0.492492
# 8                  20  UmbralCompleto               True             2.513548
# 86                 30  UmbralCompleto               True             0.380580
# 34                 30  UmbralCompleto               True             1.555351
# 9                  30  UmbralCompleto              False             2.487881
# 60                 30  UmbralCompleto               True             1.504827
# 87                 40  UmbralCompleto               True             0.407085
# 61                 40  UmbralCompleto               True             1.487434
# 10                 40  UmbralCompleto               True             2.067289
# 35                 40  UmbralCompleto               True             1.651595
# 11                 50  UmbralCompleto               True             0.934836
# 88                 50  UmbralCompleto               True             0.551098
# 62                 50  UmbralCompleto              False             1.375946
# 36                 50  UmbralCompleto               True             0.754828
# 89                 60  UmbralCompleto               True             0.561681
# 37                 60  UmbralCompleto               True             0.312811
# 12                 60  UmbralCompleto              False             4.310340
# 63                 60  UmbralCompleto               True             0.443146
# 13                 70  UmbralCompleto               True             3.046802
# 38                 70  UmbralCompleto               True             0.253677
# 90                 70  UmbralCompleto               True             0.097905
# 64                 70  UmbralCompleto               True             0.557504
# 14                 80  UmbralCompleto               True             0.761082
# 39                 80  UmbralCompleto               True             0.246318
# 91                 80  UmbralCompleto               True             0.289200
# 65                 80  UmbralCompleto               True             0.242245
# 66                 86  UmbralCompleto               True             0.072702
# 40                 86  UmbralCompleto               True             0.056784
# 15                 86  UmbralCompleto               True             1.134369
# 92                 86  UmbralCompleto               True             0.029274
# 16                 88  UmbralCompleto               True             1.456147
# 93                 88  UmbralCompleto               True             0.133907
# 41                 88  UmbralCompleto               True             0.023639
# 67                 88  UmbralCompleto               True             0.017185
# 94                 90  UmbralCompleto               True             0.025437
# 68                 90  UmbralCompleto               True             0.018871
# 0                  90  UmbralCompleto              False             0.850230
# 42                 90  UmbralCompleto              False             0.062959
# 69                 92  UmbralCompleto              False             0.098524
# 95                 92  UmbralCompleto               True             0.084157
# 43                 92  UmbralCompleto               True             0.015119
# 17                 92  UmbralCompleto              False             0.105837
# 70                 94  UmbralCompleto              False             0.071982
# 96                 94  UmbralCompleto               True             0.110751
# 18                 94  UmbralCompleto              False             0.357346
# 44                 94  UmbralCompleto               True             0.011120
# 71                100  UmbralCompleto               True             0.240681
# 20                100  UmbralCompleto               True             0.699337
# 45                100  UmbralCompleto               True             0.152383
# 97                100  UmbralCompleto               True             0.223989
# 46                110  UmbralCompleto               True             0.240947
# 98                110  UmbralCompleto              False             1.206966
# 19                110  UmbralCompleto               True             1.131326
# 72                110  UmbralCompleto               True             0.506843
# 47                120  UmbralCompleto               True             0.768348
# 21                120  UmbralCompleto               True             0.899807
# 99                120  UmbralCompleto               True             0.827938
# 73                120  UmbralCompleto               True             0.336111
# 74                130  UmbralCompleto               True             0.385669
# 100               130  UmbralCompleto               True             0.306203
# 23                130  UmbralCompleto               True             1.311521
# 48                130  UmbralCompleto               True             1.110133
# 75                140  UmbralCompleto               True             1.011393
# 101               140  UmbralCompleto               True             0.081292
# 22                140  UmbralCompleto               True             1.172902
# 49                140  UmbralCompleto               True             0.224178
# 102               150  UmbralCompleto               True             1.034979
# 112               150  UmbralCompleto               True             0.905351
# 50                150  UmbralCompleto              False             0.370868
# 76                150  UmbralCompleto               True             0.618038
# 24                150  UmbralCompleto              False             1.066040
# 25                160  UmbralCompleto               True             0.749797
# 111               160  UmbralCompleto              False             1.122809
# 103               160  UmbralCompleto              False             1.536648
# 51                160  UmbralCompleto              False             0.311153
# 77                160  UmbralCompleto               True             0.704042
# 104               170  UmbralCompleto               True             2.598075
# 52                170  UmbralCompleto               True             0.237680
# 78                170  UmbralCompleto               True             0.427229
# 110               170  UmbralCompleto               True             0.352807
# 26                170  UmbralCompleto              False             1.276649
#
# 69  2015-12-03 19:09:30.174999         Ioni1
# 95  2015-12-15 21:55:29.608999        Lizaso
# 43  2015-12-09 12:21:16.032999         Ioni2
# 17  2015-12-08 18:54:02.196000          Iael
# 70  2015-12-03 19:09:30.174999         Ioni1
# 96  2015-12-15 21:55:29.608999        Lizaso
# 18  2015-12-08 18:54:02.196000          Iael
# 44  2015-12-09 12:21:16.032999         Ioni2
# 71  2015-12-04 15:57:54.994999         Ioni1
# 20  2015-12-08 18:54:02.196000          Iael
# 45  2015-12-09 12:21:16.032999         Ioni2
# 97  2015-12-15 21:55:29.608999        Lizaso
# 46  2015-12-09 12:21:16.032999         Ioni2
# 98  2015-12-15 21:55:29.608999        Lizaso
# 19  2015-12-08 18:54:02.196000          Iael
# 72  2015-12-04 15:57:54.994999         Ioni1
# 47  2015-12-09 12:21:16.032999         Ioni2
# 21  2015-12-08 18:54:02.196000          Iael
# 99  2015-12-22 12:50:53.605999        Lizaso
# 73  2015-12-04 15:57:54.994999         Ioni1
# 74  2015-12-04 15:57:54.994999         Ioni1
# 100 2015-12-22 12:50:53.605999        Lizaso
# 23  2015-12-08 18:54:02.196000          Iael
# 48  2015-12-09 12:21:16.032999         Ioni2
# 75  2015-12-04 15:57:54.994999         Ioni1
# 101 2015-12-22 12:50:53.605999        Lizaso
# 22  2015-12-08 18:54:02.196000          Iael
# 49  2015-12-09 12:21:16.032999         Ioni2
# 102 2015-12-22 12:50:53.605999        Lizaso
# 112 2015-12-17 08:48:19.464999  Dario17del12
# 50  2015-12-09 12:21:16.032999         Ioni2
# 76  2015-12-04 15:57:54.994999         Ioni1
# 24  2015-12-08 18:54:02.196000          Iael
# 25  2015-12-08 18:54:02.196000          Iael
# 111 2015-12-17 08:48:19.464999  Dario17del12
# 103 2015-12-22 12:50:53.605999        Lizaso
# 51  2015-12-09 12:21:16.032999         Ioni2
# 77  2015-12-04 15:57:54.994999         Ioni1
# 104 2015-12-22 12:50:53.605999        Lizaso
# 52  2015-12-09 12:21:16.032999         Ioni2
# 78  2015-12-04 15:57:54.994999         Ioni1
# 110 2015-12-17 08:48:19.464999  Dario17del12
# 26  2015-12-08 18:54:02.196000          Iael

# %%
from scripts.sesgo import *

touchs, sounds = load(levelVersion=22, filtrarXUsuarioRegistrado=True)
resumen = crearTabla(touchs)
histogramaAciertosVsOrientacionVsSeparacion(resumen)
# Out:
# 'Numero de sesiones totales encontradas:: 62'
# 'Numero de levels totales encontrados: 144'
# 'Numero de trials totales encontrados: 4423'
# 'Filtrando datos...'
# 'Recursos cargados del archivo'
# 'Touchs seleccionados: 3420'
# 'Sounds seleccionados: 4598'
# 'Creando tabla resumen de la informacion de los toques en funcion de los parametros para el experimento de umbral'
# 'Extrayendo informacion de: AnguloReferencia'
# 'Extrayendo informacion de: DeltaTita'
# 'Extrayendo informacion de: SeJuntanEstimulo'
# 'Extrayendo informacion de: Separacion'
# 'Extrayendo informacion de: SeJuntanSeleccion'
# 'Resumen completado'

# %%
#touchs, sounds = load(levelVersion=22, filtrarXUsuarioRegistrado=True)
#resumen = crearTabla(touchs)
#resumen['Alias'].unique()
histogramaAciertosVsOrientacionVsSeparacion(resumen)

# %%
display (resumen.head())
# Out:
#                                  jsonMetaDataTouched  \
# 0  {'name': 'Imagen de rectas no paralelas genera...
# 1  {'name': 'Imagen de rectas no paralelas genera...
# 2  {'name': 'Imagen de rectas no paralelas genera...
# 3  {'name': 'Imagen de rectas no paralelas genera...
# 4  {'name': 'Imagen de rectas no paralelas genera...
#
#                                 jsonMetaDataEstimulo         userID Alias  \
# 0  {'name': 'Imagen de rectas no paralelas genera...  1449524935330  Iael
# 1  {'name': 'Imagen de rectas no paralelas genera...  1449524935330  Iael
# 2  {'name': 'Imagen de rectas no paralelas genera...  1449524935330  Iael
# 3  {'name': 'Imagen de rectas no paralelas genera...  1449524935330  Iael
# 4  {'name': 'Imagen de rectas no paralelas genera...  1449524935330  Iael
#
#    AnguloReferencia  DeltaTita SeJuntanEstimulo  Separacion SeJuntanSeleccion  \
# 0                90   9.999996             True          15             False
# 1                90   9.999996             True          25              True
# 2                90   6.021100            False          25             False
# 3                90   3.625364             True          25             False
# 4                90   5.303895             True          25             False
#
#   Aciertos
# 0    Error
# 1  Acierto
# 2  Acierto
# 3    Error
# 4    Error

# %%
import matplotlib.pyplot as plt
import pandas as pd
resumen.plot df.plot(kind='bar')
plt.hist (resumen['Aciertos'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d253b016a0d0> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.hist (resumen['Aciertos'])
#
# /home/ionatan/anaconda/envs/py34/lib/python3.4/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# /home/ionatan/anaconda/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5661             xmax = -np.inf
#    5662             for xi in x:
# -> 5663                 if len(xi) > 0:
#    5664                     xmin = min(xmin, xi.min())
#    5665                     xmax = max(xmax, xi.max())
#
# TypeError: len() of unsized object

# %%
DownloadFile()
join()
# Out:
# 'Downloaded: Session:7 levels:29 trials:1170'
# 'Sessions tiene 7 entradas'
# 'Levels tiene 29 entradas'
# 'Trials tiene 1164 entradas'
# 'Se agregaron 0 registros al registro de sesiones'
# 'Se agregaron 0 registros al registro de niveles'
# /home/ionatan/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/index.py:6031: RuntimeWarning: unorderable types: int() > str(), sort order is undefined for incomparable objects
#   result = result.union(other)
# 'Se agregaron 6 registros al registro de trials'
