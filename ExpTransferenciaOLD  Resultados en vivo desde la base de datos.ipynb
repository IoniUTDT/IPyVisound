# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from scripts.db import *
from scripts.plots import *
from scripts.stats import *

# %%
downloadFile()
join ()
# Out:
#  99% ( 99 of 100) |####################### | Elapsed Time: 0:00:50 ETA: 0:00:00
# 'INICIONIVEL tiene 528 entradas.'
# 'INICIONIVEL paso a tener 536 entradas.'
# 'RESULTADOS tiene 462 entradas.'
# 'RESULTADOS paso a tener 470 entradas.'
# 'SESION tiene 291 entradas.'
# 'SESION paso a tener 293 entradas.'

# %%
plotByUser(alias = ['ExpT_Marco'], onlyOneUser=False, number=-2, join=True, filtroCompletadoActivo=True)

# %%
listOfUsersClean()

# %%
updateListOfUsers(notIgnored=True)

# %%
usersResumen()
# Out:
# "El usuario ExpT_Marco realizo entrenamiento en ['A30' 'P30']"
# "Y realizo los siguientes niveles: ['Tutorial' 'TestInicial' 'Entrenamiento1' 'Entrenamiento2'\n 'Entrenamiento3' 'Entrenamiento4']"
# "El usuario ExpT_Carolina realizo entrenamiento en ['A30']"
# "Y realizo los siguientes niveles: ['Tutorial' 'TestInicial' 'Entrenamiento1' 'Entrenamiento2'\n 'Entrenamiento4' 'Entrenamiento3' 'TestFinal']"
# "El usuario ExpT_Magdalena realizo entrenamiento en ['A30' 'P30']"
# "Y realizo los siguientes niveles: ['Tutorial' 'TestInicial' 'Entrenamiento1' 'Entrenamiento2'\n 'Entrenamiento3' 'Entrenamiento4' 'TestFinal']"
# "El usuario ExpT_Ivan realizo entrenamiento en ['P30']"
# "Y realizo los siguientes niveles: ['Tutorial' 'TestInicial' 'Entrenamiento1']"
# "El usuario ExpT_Enzo realizo entrenamiento en ['P30']"
# "Y realizo los siguientes niveles: ['Tutorial' 'TestInicial' 'Entrenamiento1' 'Entrenamiento2'\n 'Entrenamiento3']"
# ...

# %%
listOfUsers()
