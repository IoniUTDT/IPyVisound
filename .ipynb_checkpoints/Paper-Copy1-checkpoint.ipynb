# %%
from scripts.db import *
from scripts.plots import *
from scripts.stats import *
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline
from sklearn import linear_model
import os
import json

# %%
users, db = dataProcesada(filtroCompletadoActivo=False)

# %%
data = db
data = data[['alias', 'userId', 'EnvioInstance','Finalizado', 'OrientacionEntrenamiento', 'Refrencia', 'faseActiva','identificadorNivel', 'levelInstance', 'sessionInstance', 'AnguloFijo','Desviacion', 'IdEstimulo', 'NivelSenalDinamica', 'NivelSenalEstimulo', 'RtaCorrecta','TipoDeTrial']]
data = data[data['faseActiva']!='Tutorial']


mapNames = {'ExpT_Marco':'Sujeto01','ExpT_Carolina':'Sujeto02','ExpT_Magdalena':'Sujeto03','ExpT_Ivan':'Sujeto04','ExpT_Enzo':'Sujeto05',
            'ExpT_Julieta':'Sujeto06','ExpT_Gaston':'Sujeto07','ExpT_Andres':'Sujeto08','ExpT_CaroG':'Sujeto09','ExpT_Michelle':'Sujeto10'}

data['sujetos'] = data['alias'].map(mapNames)
#Datos perdidos
# Carolina primer test entrenamiento
# Magdalena primer entrenamiento ultimo dia
# Enzo primero del segundo dia

# %% [markdown]
# Vamos a hacer un analisis sujeto por sujeto

# %%
Sujeto = 1

# Filtramos la data

dataS = data[data['sujetos']=='Sujeto0'+str(Sujeto)]

# dataS = dataS.drop_duplicates()
#dataS = dataS[dataS['EnvioInstance']!=1472739152993]
#dataS.ix[dataS['levelInstance']==1473429833367,'faseActiva'] = 'Entrenamiento3'
# El sujeto 1 entreno en agulos
levels = dataS['levelInstance'].unique()
levels.sort()
if Sujeto == 1:
    levelsAProcesar= [levels[4],levels[8],levels[9],levels[10],levels[11],levels[12],levels[13],levels[14],levels[15],levels[16],levels[17],levels[18],levels[19],levels[24]]
if Sujeto == 2:
    levelsAProcesar= [levels[5],levels[9],levels[10],levels[11],levels[12],levels[13],levels[14],levels[17],levels[16],levels[15],levels[18],levels[19],levels[20],levels[25]]

dataConjunta = pd.DataFrame()

for level in levelsAProcesar:
    dataP = data[data['levelInstance']==level]
    if level == 1472738524843:
        dataP = dataP.iloc[0:100]
        dataP[63:100] = np.nan
    if Sujeto in [1,2]:
        AMax = 79.6
        N = 200
        paso=AMax/N
        dataP['medida'] = (dataP['NivelSenalDinamica']+1)*paso
        
    if len (dataConjunta)>0: 
        dataConjunta = pd.concat([dataConjunta,dataP])
    else:
        dataConjunta = dataP
# Out:
# /usr/local/lib/python3.4/dist-packages/ipykernel/__main__.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mapColor = {'TestInicial':'black', 'Entrenamiento1':'green', 'Entrenamiento2':'red', 'Entrenamiento3':'blue',
       'Entrenamiento4':'gray', 'TestFinal':'black'}


vmin=30

ventana = 100

TestInicial = False
TestFinal = False

if TestInicial:
    inicio=0
else:
    inicio = 40
    
if TestFinal:
    final=len(dataConjunta)
else:
    final=len(dataConjunta)-40



def model(x):
    return 1 / (1 + np.exp(-x))


for i in np.arange(inicio,final):
    
    if ventana < 0:
        if i-inicio<vmin:
            continue
        else:
            Ni=inicio
            Nf=i
    else:
        if i-ventana < inicio:
            continue
        else:
            Ni=i-ventana
            Nf=i
    
    
    
    X = np.array(dataConjunta["medida"])[Ni:Nf, np.newaxis]
    y = np.array(dataConjunta["RtaCorrecta"].astype(float))[Ni:Nf]

    clf = linear_model.LogisticRegression(C=1e5)
    clf.fit(X, y)

    # and plot the result
    fig, ax = plt.subplots(1,1,figsize=(4, 3))
    ax.set_xlim([-5,85])
    if ventana>0:
        ax.set_title(dataConjunta.iloc[0]['sujetos']+', entrenamiento en ángulos \n' + 'dia '+dataConjunta['faseActiva'].iloc[Nf-1][-1]+'\n trials de entrenamiento realizados: '+ str(Nf-40)+' \n ajuste considerando los últimos '+str(ventana))
    else:
        ax.set_title(dataConjunta.iloc[0]['sujetos']+', entrenamiento en ángulos \n' + 'dia '+dataConjunta['faseActiva'].iloc[Nf-1][-1]+'\n trials de entrenamiento realizados: '+ str(Nf-40))
    ax.scatter(X, y, color='black', zorder=20)
    ax.scatter(X[-1], y[-1], color='yellow', zorder=20)
    X_test = np.linspace(min(X), max(X), 300)

    loss = model(X_test * clf.coef_ + clf.intercept_).ravel()
    ax.plot(X_test, loss, color=mapColor[dataConjunta['faseActiva'].iloc[Nf-1]], linewidth=3)

    ax.axhline(y=0.77,linewidth=0.5, color='y', linestyle='dashed')
    ax.set_xlabel('Distancia al ángulo recto (º)')
    ax.set_yticks([0,0.77,1]) 
    ax.set_yticklabels(['Error','Esperado','Acierto'])
    
    directory = './Series/'+dataConjunta.iloc[0]['sujetos']+'_ventana_'+str(ventana)+'rango:'
    if not os.path.exists(directory):
        os.makedirs(directory)
    plt.savefig(directory+'/img'+str(i)+'.png', dpi=300, bbox_inches='tight')
    #break
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
i-ventana
# Out:
# 41

# %%
clf.predict_proba(X)
x = np.arange(0,80)[:, np.newaxis]
resultado = clf.predict_proba(x)

len (resultado)
# Out:
# 80

# %%
min(X)
# Out:
# array([ 42.984])

# %%
inicio
# Out:
# 40

# %%
dataPrueba = data[data['alias']=='ExpT_Carolina']
pepe = dataPrueba[dataPrueba['levelInstance']==1472738524843]

# %%
pepe
# Out:
#              alias         userId  EnvioInstance Finalizado  \
# 680  ExpT_Carolina  1472735163595  1472739152992      False
# 681  ExpT_Carolina  1472735163595  1472739152992      False
# 682  ExpT_Carolina  1472735163595  1472739152992      False
# 683  ExpT_Carolina  1472735163595  1472739152992      False
# 684  ExpT_Carolina  1472735163595  1472739152992      False
# 685  ExpT_Carolina  1472735163595  1472739152992      False
# 925  ExpT_Carolina  1472735163595  1472739152993      False
# 926  ExpT_Carolina  1472735163595  1472739152993      False
# 927  ExpT_Carolina  1472735163595  1472739152993      False
#
#     OrientacionEntrenamiento  Refrencia      faseActiva  \
# 680                      A30         30  Entrenamiento1
# 681                      A30         30  Entrenamiento1
# 682                      A30         30  Entrenamiento1
# 683                      A30         30  Entrenamiento1
# 684                      A30         30  Entrenamiento1
# 685                      A30         30  Entrenamiento1
# 686                      A30         30  Entrenamiento1
# 687                      A30         30  Entrenamiento1
# 688                      A30         30  Entrenamiento1
# 689                      A30         30  Entrenamiento1
# 690                      A30         30  Entrenamiento1
# 691                      A30         30  Entrenamiento1
# 692                      A30         30  Entrenamiento1
# 693                      A30         30  Entrenamiento1
# 694                      A30         30  Entrenamiento1
# 695                      A30         30  Entrenamiento1
# 696                      A30         30  Entrenamiento1
# 697                      A30         30  Entrenamiento1
# 698                      A30         30  Entrenamiento1
# 699                      A30         30  Entrenamiento1
# 700                      A30         30  Entrenamiento1
# 701                      A30         30  Entrenamiento1
# 702                      A30         30  Entrenamiento1
# 703                      A30         30  Entrenamiento1
# 704                      A30         30  Entrenamiento1
# 705                      A30         30  Entrenamiento1
# 706                      A30         30  Entrenamiento1
# 707                      A30         30  Entrenamiento1
# 708                      A30         30  Entrenamiento1
# 709                      A30         30  Entrenamiento1
# ..                       ...        ...             ...
# 898                      A30         30  Entrenamiento1
# 899                      A30         30  Entrenamiento1
# 900                      A30         30  Entrenamiento1
# 901                      A30         30  Entrenamiento1
# 902                      A30         30  Entrenamiento1
# 903                      A30         30  Entrenamiento1
# 904                      A30         30  Entrenamiento1
# 905                      A30         30  Entrenamiento1
# 906                      A30         30  Entrenamiento1
# 907                      A30         30  Entrenamiento1
# 908                      A30         30  Entrenamiento1
# 909                      A30         30  Entrenamiento1
# 910                      A30         30  Entrenamiento1
# 911                      A30         30  Entrenamiento1
# 912                      A30         30  Entrenamiento1
# 913                      A30         30  Entrenamiento1
# 914                      A30         30  Entrenamiento1
# 915                      A30         30  Entrenamiento1
# 916                      A30         30  Entrenamiento1
# 917                      A30         30  Entrenamiento1
# 918                      A30         30  Entrenamiento1
# 919                      A30         30  Entrenamiento1
# 920                      A30         30  Entrenamiento1
# 921                      A30         30  Entrenamiento1
# 922                      A30         30  Entrenamiento1
# 923                      A30         30  Entrenamiento1
# 924                      A30         30  Entrenamiento1
# 925                      A30         30  Entrenamiento1
# 926                      A30         30  Entrenamiento1
# 927                      A30         30  Entrenamiento1
#
#           identificadorNivel  levelInstance  sessionInstance  AnguloFijo  \
# 680  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        32.5
# 681  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        32.5
# 682  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        35.0
# 683  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        25.0
# 684  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        23.0
# 685  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        32.5
# 686  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        30.0
# 687  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        36.0
# 688  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        30.0
# 689  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        30.0
# 690  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        25.0
# 691  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        36.0
# 692  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319        25.0
# 693  ENTRENAMIENTOA30INICIAL  1472738524843    1472735915319
# 917    -137.215         252                 117                 118
# 918    -169.605        1770                 105                 200
# 919     -90.000        8174                 105                   0
# 920     -90.000        8183                 108                   0
# 921     -90.000        8176                 108                   0
# 922     -90.000        8175                 105                   0
# 923     -90.000        8174                 105                   0
# 924     -49.895        1269                  99                 100
# 925     -49.895         869                  99                 100
# 926     -53.450        1260                  90                  91
# 927     -90.000        8174                  90                   0
#
#     RtaCorrecta TipoDeTrial   sujetos
# 680        True    Estimulo  Sujeto02
# 681        True    Estimulo  Sujeto02
# 682        True        Test  Sujeto02
# 683        True    Estimulo  Sujeto02
# 684       False  NoEstimulo  Sujeto02
# 685       False    Estimulo  Sujeto02
# 686        True    Estimulo  Sujeto02
# 687       False  NoEstimulo  Sujeto02
# 688        True  NoEstimulo  Sujeto02
# 689        True    Estimulo  Sujeto02
# 690        True    Estimulo  Sujeto02
# 691       False  NoEstimulo  Sujeto02
# 692        True    Estimulo  Sujeto02
# 693        True    Estimulo  Sujeto02
# 694       False  NoEstimulo  Sujeto02
# 695        True  NoEstimulo  Sujeto02
# 696       False  NoEstimulo  Sujeto02
# 697        True    Estimulo  Sujeto02
# 698        True    Estimulo  Sujeto02
# 699        True    Estimulo  Sujeto02
# 700        True  NoEstimulo  Sujeto02
# 701        True  NoEstimulo  Sujeto02
# 702       False    Estimulo  Sujeto02
# 703        True    Estimulo  Sujeto02
# 704        True    Estimulo  Sujeto02
# 705       False    Estimulo  Sujeto02
# 706       False  NoEstimulo  Sujeto02
# 707       False  NoEstimulo  Sujeto02
# 708        True  NoEstimulo  Sujeto02
# 709        True    Estimulo  Sujeto02
# ..          ...         ...       ...
# 898       False    Estimulo  Sujeto02
# 899        True    Estimulo  Sujeto02
# 900       False  NoEstimulo  Sujeto02
# 901        True  NoEstimulo  Sujeto02
# 902        True    Estimulo  Sujeto02
# 903        True    Estimulo  Sujeto02
# 904        True    Estimulo  Sujeto02
# 905        True  NoEstimulo  Sujeto02
# 906       False    Estimulo  Sujeto02
# 907        True  NoEstimulo  Sujeto02
# 908        True    Estimulo  Sujeto02
# 909       False    Estimulo  Sujeto02
# 910        True  NoEstimulo  Sujeto02
# 911        True  NoEstimulo  Sujeto02
# 912        True  NoEstimulo  Sujeto02
# 913        True  NoEstimulo  Sujeto02
# 914        True  NoEstimulo  Sujeto02
# 915        True  NoEstimulo  Sujeto02
# 916        True    Estimulo  Sujeto02
# 917        True    Estimulo  Sujeto02
# 918        True        Test  Sujeto02
# 919       False  NoEstimulo  Sujeto02
# 920        True  NoEstimulo  Sujeto02
# 921        True  NoEstimulo  Sujeto02
# 922        True  NoEstimulo  Sujeto02
# 923        True  NoEstimulo  Sujeto02
# 924        True    Estimulo  Sujeto02
# 925        True    Estimulo  Sujeto02
# 926        True    Estimulo  Sujeto02
# 927       False  NoEstimulo  Sujeto02
#
# [248 rows x 18 columns]
